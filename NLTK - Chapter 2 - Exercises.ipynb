# %% [markdown]
# ☼ 1. Create a variable phrase containing a list of words. Review the operations described in the previous chapter, including addition, multiplication, indexing, slicing, and sorting.

# %%
phrase = 'oi, tudo bem, como vai voce '
print('original:\n',phrase)
print('\n')

dialogue = phrase + '\ntudo bem'
print('addition:\n', dialogue)
print('\n')

repeatQuestion = phrase*2
print('multiplication:\n', repeatQuestion)
print('\n')

indexComma = phrase[2]
print('indexing:\n', indexComma)
print('\n')

justTudo = phrase[4:9]
print('slicing:\n', justTudo)
print('\n')

print('sorting:\n', sorted(phrase))
print('\n')

print('end')
# Out:
# original:
#  oi, tudo bem, como vai voce
#
#
# addition:
#  oi, tudo bem, como vai voce
# tudo bem
#
#
# multiplication:
#  oi, tudo bem, como vai voce oi, tudo bem, como vai voce
#
#
# indexing:
#  ,
#
#
# slicing:
#  tudo
#
#
# sorting:
#  [' ', ' ', ' ', ' ', ' ', ' ', ',', ',', 'a', 'b', 'c', 'c', 'd', 'e', 'e', 'i', 'i', 'm', 'm', 'o', 'o', 'o', 'o', 'o', 't', 'u', 'v', 'v']
#
#
# end

# %% [markdown]
# ☼ 2. Use the corpus module to explore austen-persuasion.txt. How many word tokens does this book have? How many word types?

# %%
from nltk.corpus import gutenberg
emma = gutenberg.words('austen-emma.txt')

print('number of tokens = ', len(emma))

uniqueWords = set(emma)
print('number of word types:', len(uniqueWords))

print('\nend')
# Out:
# number of tokens =  192427
# number of word types: 7811
#
# end

# %% [markdown]
# ☼ 3. Use the Brown corpus reader nltk.corpus.brown.words() or the Web text corpus reader nltk.corpus.webtext.words() to access some sample text in two different genres.

# %%
from nltk.corpus import brown

sampleMystery = brown.words(categories = 'mystery')
print('mistery: ', sampleMystery)

sampleSciFi = brown.words(categories = 'science_fiction')
print('science fiction: ',sampleSciFi)

print('\nend')

brown.fileids('news')
# Out:
# mistery:  ['There', 'were', 'thirty-eight', 'patients', 'on', ...]
# science fiction:  ['Now', 'that', 'he', 'knew', 'himself', 'to', 'be', ...]
#
# end
# ['ca01',
#  'ca02',
#  'ca03',
#  'ca04',
#  'ca05',
#  'ca06',
#  'ca07',
#  'ca08',
#  'ca09',
#  'ca10',
#  'ca11',
#  'ca12',
#  'ca13',
#  'ca14',
#  'ca15',
#  'ca16',
#  'ca17',
#  'ca18',
#  'ca19',
#  'ca20',
#  'ca21',
#  'ca22',
#  'ca23',
#  'ca24',
#  'ca25',
#  'ca26',
#  'ca27',
#  'ca28',
#  'ca29',
#  'ca30',
#  'ca31',
#  'ca32',
#  'ca33',
#  'ca34',
#  'ca35',
#  'ca36',
#  'ca37',
#  'ca38',
#  'ca39',
#  'ca40',
#  'ca41',
#  'ca42',
#  'ca43',
#  'ca44']

# %% [markdown]
# ☼ 4. Read in the texts of the State of the Union addresses, using the state_union corpus reader. Count occurrences of men, women, and people in each document. What has happened to the usage of these words over time?

# %%
import nltk
from nltk.corpus import state_union
cfd = nltk.ConditionalFreqDist(
    (target, fileid[:4])
    for fileid in state_union.fileids()
    for w in state_union.words(fileid)
    for target in ['men', 'women', 'people']
    if w.lower().startswith(target)) 
cfd.plot()

# %% [markdown]
# ☼ 5. Investigate the holonym-meronym relations for some nouns. Remember that there are three kinds of holonym-meronym relation, so you need to use: member_meronyms(),  part_meronyms(), substance_meronyms(), member_holonyms(), part_holonyms(), and substance_holonyms().

# %% [markdown]
# ☼ 6. In the discussion of comparative wordlists, we created an object called translate which you could look up using words in both German and Spanish in order to get corresponding words in English. What problem might arise with this approach? Can you suggest a way to avoid this problem?

# %% [markdown]
# ☼ 7. According to Strunk and White's Elements of Style, the word however, used at the start of a sentence, means "in whatever way" or "to whatever extent", and not "nevertheless". They give this example of correct usage: However you advise him, he will probably do as he thinks best. (http://www.bartleby.com/141/strunk3.html) Use the concordance tool to study actual usage of this word in the various texts we have been considering. See also the LanguageLog posting "Fossilized prejudices about 'however'" at http://itre.cis.upenn.edu/~myl/languagelog/archives/001913.html

# %%
from nltk.corpus import state_union
from nltk.text import Text 
for fileid in state_union.fileids():
    text = Text(state_union.words(fileid))
    text.concordance('however')
# Out:
# Displaying 2 of 2 matches:
#  impunity at any mountain retreat - however distant . In this shrinking world ,
# roblems of staggering proportions . However , with the faith of our fathers in
# Displaying 21 of 21 matches:
# interests . Neither do we propose , however , to ignore the ideals and vital in
# challenging task . In my judgment , however , the Council has made encouraging
# standing accomplishment . We know , however , that nothing is as dangerous as o
# ormation . Certain tendencies are , however , fairly clear and recognition of t
# he next year . This does not mean , however , that continuing full employment i
# yed worker . There always will be , however , some frictional unemployment . In
# nd good will . The Government can , however , help to develop machinery which ,
# cases arising in the months ahead . However , everyone who realizes the extreme
#  the transition from war to peace . However , when deferred demand slackens , w
# ens . We want to keep it that way . However , it is the Government ' s responsi
# f living . As matters stand today , however , food prices are pressing hard aga
#  and as expeditiously as possible . However , we know that there will continue
# he chief dependence of the farmer , however , as always , must be upon the buyi
# as begun to taper off . Meanwhile , however , plans should be prepared if we ar
# vages of war and enemy occupation , however , have placed a heavy responsibilit
# mployed . On the expenditure side , however , consumers budgets , restricted du
# d impair the reemployment program . However , in order to preserve the fine wor
# s to be expected and is necessary . However , substantial further rescissions c
# ission and certain other agencies , however , I now make specific recommendatio
# nance of our position as a nation , however , will require more emphasis on res
#  of our national welfare . We can , however , enhance its operating efficiency
# Displaying 6 of 6 matches:
# of opinion . Partisan differences , however , did not cause material disagreeme
# trikes and lockouts . We must not , however , adopt punitive legislation . We m
# . In some jurisdictional disputes , however , minority unions strike to compel
# sfactory . Whatever their defects , however , I am convinced that they are as g
# n between us and the Soviet Union , however , should not be allowed to obscure
# than all other countries combined . However , insofar as admitting displaced pe
# Displaying 5 of 5 matches:
# ms and factories . More important , however , is the fact that these years brou
#  worth of each individual . Today , however , some of our citizens are still de
# n the United States . The fact is , however , that most of our p eople cannot a
#  to 75 cents an hour . In general , however , we must continue to rely on our s
# as it remains the law of the land , however , I shall carry out my constitution
# Displaying 1 of 1 matches:
# he Wagner Act should be reenacted . However , certain improvements , which I re
# Displaying 3 of 3 matches:
# While the world remains unsettled , however , and as long as our own security a
# , can foretell the future exactly . However , if we assume that we shall grow a
#  the last session of the Congress . However , our farm legislation is still not
# Displaying 2 of 2 matches:
#  never command . The free nations , however , are bound together by more than i
# n arms production . In many cases , however , our stocks of weapons are low . I
# Displaying 2 of 2 matches:
# a role to play . Our whole system , however , is based upon the assumption that
# d our freedom . It is well for us , however , to remind ourselves occasionally
# Displaying 3 of 3 matches:
# conomic assistance can be reduced . However , our economic programs in Korea an
#  of 3947 is basically a sound law . However , six years of experience have reve
#  a state and local responsibility . However , the Federal Government should sta
# Displaying 5 of 5 matches:
# ntee sustained economic expansion ; however , they do give us a strong position
# d Federal laws and authorizations . However , this effort will not in itself as
# ference to be completed this year . However , such factors as population growth
# d - age and survivors ' insurance . However , these systems also are a basic pa
# opped . Certain provisions of law , however , have the effect of compelling act
# Displaying 4 of 4 matches:
# articipation in relief activities , however , has been far from uniform and , i
# islative authority already exists . However , a firm program of public housing
# er the Refugee Relief Act of 1953 ; however , I again request this Congress to
# Republic may be judged . Progress , however , will be realized only as it is mo
# Displaying 1 of 1 matches:
# ncreases that outrun productivity , however , are an inflationary factor . They
# no matches
# Displaying 1 of 1 matches:
# ice stability for economic growth . However , certain additional measures are n
# Displaying 2 of 2 matches:
# gotiate seriously . They have not , however , made clear the plans they may hav
# ance with its own . We realize that however much we repudiate the tenets of imp
# no matches
# no matches
# no matches
# Displaying 2 of 2 matches:
# t home . II . Tax reduction alone , however , is not enough to strengthen our s
# er money nor technical assistance , however , can be our only weapon against po
# Displaying 2 of 2 matches:
#  . No single piece of legislation , however , is going to suffice . We will lau
# February , if at all possible . For however proud we may be of the unprecedente
# no matches
# Displaying 1 of 1 matches:
# orm standard which cannot be used , however ingenious the effort , to flout our
# no matches
# Displaying 1 of 1 matches:
# ared to see our assistance wasted , however , in conflict . It must strengthen
# Displaying 1 of 1 matches:
# r own borders . The United States , however , remains willing to permit the tra
# no matches
# no matches
# no matches
# Displaying 2 of 2 matches:
# nd on some domestic policy issues . However , there are great national problems
# y . But all these recommendations , however , will be rooted in one fundamental
# Displaying 1 of 1 matches:
# on have multiplied over the years , however , so too have the subjects that req
# Displaying 2 of 2 matches:
# rgo . This is an encouraging sign . However , it should be clearly understood b
#  . 2 million . In the coming year , however , increased expenditures will be ne
# no matches
# no matches
# Displaying 1 of 1 matches:
# ll ever see . We can be confident , however , that 100 years from now a freely
# Displaying 1 of 1 matches:
# are who are able to work can work . However , again , we know that in our free
# no matches
# Displaying 1 of 1 matches:
# ecome necessary to impose a draft . However , we must be prepared for that poss
# Displaying 4 of 4 matches:
# tal cost of education . They will , however , restore more authority to States
# icient nutritional food . We will , however , save $ 1 . 8 billion in fiscal ye
#  plan to continue it . We believe , however , that a reordering of priorities t
# sure the public health and safety . However , we must come to grips with ineffi
# Displaying 3 of 3 matches:
# nemployment increased . This time , however , things are different . We have an
# his program . I want to emphasize , however , that its full details will have b
#  in the near future . A few words , however , are in order on the progress we '
# Displaying 1 of 1 matches:
# can understand . At the same time , however , I will oppose any efforts to undo
# no matches
# no matches
# Displaying 1 of 1 matches:
# rosperity , liberty , and democracy however and wherever we can . We advance th
# Displaying 1 of 1 matches:
#  put wind in the sails of freedom . However , we must always remember that our
# no matches
# Displaying 1 of 1 matches:
# elling need to reduce the deficit , however , I support a 1 - year freeze in th
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# Displaying 1 of 1 matches:
# pose to match their contributions , however small , dollar for dollar , every y
# no matches
# Displaying 1 of 1 matches:
# proud . ( Applause .) This is not , however , just America ' s fight . And what
# no matches
# Displaying 1 of 1 matches:
# ruction . In all of these efforts , however , America ' s purpose is more than
# Displaying 2 of 2 matches:
# h support . There is a difference , however , between leading a coalition of ma
# or other states . Activist judges , however , have begun redefining marriage by
# Displaying 2 of 2 matches:
# entury . ( Applause .) The system , however , on its current path , is headed t
#  to offer . ( Applause .) We must , however , be guided by some basic principle
# Displaying 1 of 1 matches:
# eans little . Members of Congress , however we feel about the decisions and deb

# %%
for fileid in brown.fileids():
    text = Text(brown.words(fileid))
    text.concordance('however')
print('\nend')
# Out:
# Displaying 3 of 3 matches:
# th governments '' . Merger proposed However , the jury said it believes `` thes
# ment source told The Constitution , however , that Vandiver has not been consul
#  to the election was not so quiet , however . It was marked by controversy , an
# no matches
# no matches
# Displaying 1 of 1 matches:
#  . ( Some SEATO nations disagreed , however . ) There was the further complicat
# no matches
# no matches
# Displaying 1 of 1 matches:
# icans . The Democratic leadership , however , hopes to pass it sometime this we
# no matches
# no matches
# Displaying 1 of 1 matches:
# minor editing and clarification ; ; however , the first belief stood for entire
# no matches
# Displaying 1 of 1 matches:
#  your timing gets off '' . Moritz , however , kicks only about 10 or 12 extra p
# Displaying 1 of 1 matches:
#  or pro-Yankee . The record books , however , would favor the Giants' ace . In
# Displaying 4 of 4 matches:
#  Van Brocklin's aerials . Skorich , however , is a strong advocate of a balance
# standpoint of the army of duffers , however , this was easily the most hearteni
# at stroke . Until a few weeks ago , however , Arnold Palmer was some god-like c
# ainst teams in the other division . However , this would require a lengthening
# no matches
# Displaying 2 of 2 matches:
# ro Beach , Fla. , for the wedding . However , Mr. Parichy and his bride will go
# ts club . It won't be a `` tea '' , however , but more of an international folk
# no matches
# no matches
# Displaying 1 of 1 matches:
# heir meetings . Dr. Jenkins notes , however , that most of the school boards in
# Displaying 1 of 1 matches:
# atomic submarine . Its power unit , however , was derived from the reactor of t
# Displaying 1 of 1 matches:
#  admitted killing Mrs. Hengesbach . However , the confession , which was the on
# Displaying 3 of 3 matches:
# on . An Emory spokesman indicated , however , that the university itself did no
# hat it was not in the Friday mail . However , three of the managers did say tha
#  . Several theater operators said , however , that there is little likelihood o
# Displaying 1 of 1 matches:
# y allotment had yet been received , however . Board oks pact The commission , m
# no matches
# no matches
# Displaying 1 of 1 matches:
# 14 per cent over February's 2,963 . However , compared with March 1960 new car
# Displaying 1 of 1 matches:
# fore the American Marketing Assn. . However , Peterson , president of Bell & Ho
# Displaying 2 of 2 matches:
# l sections are showing an upswing , however ; ; the drought-seared North Centra
# a plan of liquidation . Louisiana , however , collected an income tax on the pr
# Displaying 1 of 1 matches:
#  '' . A favorite is Norman Norell , however . She likes his classic chemise . H
# Displaying 3 of 3 matches:
# w up in Illinois '' . I explained , however , that I had my share of hardship i
# solution , naturally , is the bus . However , it's a half-mile walk down a stee
# the background lurked the feeling , however , that these pieces , beautiful as
# no matches
# Displaying 1 of 1 matches:
# , skip it . These qualities alone , however , would not account for their succe
# Displaying 1 of 1 matches:
# e . She was not present yesterday , however , to enjoy the music or watch the f
# Displaying 2 of 2 matches:
# lopments over the next two months , however , caused the President to reconside
# ther countries . The meeting will , however , afford a timely and convenient op
# Displaying 5 of 5 matches:
#  system into existence . There is , however , one curious discrepancy in this b
#  be understandable enough : it is , however , in fact difficult to see how dioc
# igious as paid employees . There is however no point in speculating about such
#  esprit de corps run riot . Apart , however , from the question of wasteful dup
# was a not inapt description . Today however , the `` outsider '' is likely to h
# Displaying 1 of 1 matches:
# acturers is hardly such a vehicle . However , one can argue that no such contro
# no matches
# no matches
# no matches
# no matches
# Displaying 2 of 2 matches:
# d to wait until the Congo grew up . However , the positions of all parties and
# and appealed to Russia for help . ( However , there is little evidence that the
# Displaying 2 of 2 matches:
# the admission of Outer Mongolia ; ; however the President , who would like to w
#  . With the money all but in hand , however , the Administration indicated that
# Displaying 4 of 4 matches:
# nds have slipped a bit since then . However , in the same three-month period ,
# es . Tax-free returns . Investors , however , still see an element of more-than
# ced with more of the same . These , however , are exceptions . The typical pict
# ds will pay out in full . Already , however , several of the turnpikes are earn
# Displaying 2 of 2 matches:
# ds . In some parts of the country , however , a co-operative movement has begun
# rs of the board . Within a system , however , the autonomy of each member libra
# Displaying 1 of 1 matches:
#  issue . No action has been taken , however , on such major problems as ending
# no matches
# no matches
# Displaying 1 of 1 matches:
# plementation of these noble words , however , has taken the efforts of five ses
# no matches
# Displaying 2 of 2 matches:
#  politics . As a former President , however , Mr. Eisenhower abandoned this rol
#  Nothing that is likely to happen , however , should prompt the sending of Unit
# no matches
# no matches
# Displaying 1 of 1 matches:
# ation of courtesy on the freeways , however , does an injustice to Southern Cal
# no matches
# no matches
# Displaying 5 of 5 matches:
#  of all translations of the Bible . However , Biblical scholars frequently atte
# ges as has the King James Version . However , an initial perusal and comparison
# evelation the new version retains , however , the old phrase `` angel of the ch
# ly contemporary For the most part , however , the new version is contemporary a
# k the truth . There is one danger , however . With contemporary English changin
# Displaying 1 of 1 matches:
#  Edison could hardly have guessed , however , that Sophocles would one day appe
# no matches
# Displaying 1 of 1 matches:
# ention needed during an emergency . However , the East Providence Rescue Squad
# no matches
# no matches
# Displaying 1 of 1 matches:
# brought about new ways of dialing . However , there are still several types of
# Displaying 3 of 3 matches:
# ss task . According to one report , however , Mr. Hammarskjold was considered `
# uylkill Expressway are valuable ; ; however , several pertinent considerations
# ion to the problem has some merit . However , he states unequivocally `` the sc
# Displaying 2 of 2 matches:
# aton bombs apiece . Some time ago , however , Mr. Khrushchev decided that when
#  still stands . Nikita Khrushchev , however , has created yet another problem f
# no matches
# Displaying 3 of 3 matches:
# intransigence at the Geneva talks , however , the hope that this third choice w
# reasonable . We take the position , however , that the third choice still remai
# the Church . As it has turned out , however , the excessive enthusiasm in the f
# no matches
# no matches
# no matches
# Displaying 1 of 1 matches:
# this no loyal citizen can quarrel . However , it seems axiomatic that the gover
# Displaying 2 of 2 matches:
# libly summarized by a commentator . However , last night the tapes were not run
# hought ) during the evening hours . However , by comparing the TV snatches , tw
# Displaying 1 of 1 matches:
# iers . They are willing to settle , however , in anything that offers pheasants
# Displaying 4 of 4 matches:
# mood of the late teens and 1920's . However well chosen and cleverly arranged ,
# he fullness of her vocal splendor , however , she could sing the famous scene m
#  remarkably well . Only too often , however , you have the feeling that you are
#  SP-44007 ) . All of the releases , however , are recorded at a gratifyingly hi
# Displaying 1 of 1 matches:
#  to enjoyment of the performances , however , except in the case of the opening
# Displaying 1 of 1 matches:
#  the part called for . I must say , however , that I preferred the acting that
# no matches
# Displaying 1 of 1 matches:
# y strength . It is quite probable , however , that stupidity , inexperience and
# no matches
# Displaying 2 of 2 matches:
# le work is like . What we did get , however , was impressive . A few drops of r
# his he is sticking with tradition , however far removed from it he may seem to
# Displaying 1 of 1 matches:
# esent time . One thing is certain , however , and that is that he is far more s
# Displaying 1 of 1 matches:
# y staying off the stage . Seigner , however , is a fine actor and probably the
# Displaying 2 of 2 matches:
# had chosen to sing . No orchestra , however , could be expected to follow a sin
# away at this point . On the whole , however , one must wonder at just what it i
# Displaying 3 of 3 matches:
# d Robert Henri . As early as 1928 , however , the Sloan style began to change .
#  resented . Not all the paintings , however , are of cities . The exhibition to
# horus ) was worth all the waiting , however , as the young Rhenish voices final
# no matches
# no matches
# no matches
# Displaying 4 of 4 matches:
# ing Mr. Remarque hoped to tell us . However , my principal objection in this so
#  compulsively strives to be liked . However , she really does not know how to m
#  it had not been for Hitler's war . However , Montgomery makes little contribut
# tarist's suspicion of politicians . However , at the same time Montgomery selec
# no matches
# Displaying 3 of 3 matches:
# ghtly grateful . All this has not , however , been an unmixed blessing . The sc
# ugh the air . As the play unfolds , however , the audience is subtly brought in
# he play , he says at one point : `` However , that experience never raised a do
# Displaying 3 of 3 matches:
# he pundits seem to have suspected . However , even if the latent demand for dem
# ion in the church ( which derives , however , from the heritage of the Greeks r
# dition is an enduring achievement . However much we may have to criticize liber
# Displaying 1 of 1 matches:
# ted country . Since arriving here , however , I have formed a far different rel
# Displaying 1 of 1 matches:
# ure . Recent research on Irenaeus , however , makes it evident that he does not
# Displaying 2 of 2 matches:
# rvative has ever to worry about ? ? However , there is a crucial difference bet
# ure , come to a fresh realization , however painful it be , that the battle bet
# Displaying 1 of 1 matches:
# her critics , like the modernists , however , overreached themselves , in claim
# no matches
# Displaying 1 of 1 matches:
# lly in connection with divination . However , the wei books were also destroyed
# Displaying 1 of 1 matches:
# ack door because of lost interest . However , it is not enough to bring persons
# Displaying 1 of 1 matches:
# pudiation of the other . Actually , however , this turns out to be only part of
# Displaying 2 of 2 matches:
# kind by man's own action . I mean , however , that the moral theologian knows w
# fied : it is `` a possible result , however improbable '' ; ; `` the worst , an
# Displaying 2 of 2 matches:
# on on Race and Housing and others , however , point to a vast complex of factor
# sideration . Relevant `` facts '' , however , extend beyond considerations of p
# no matches
# no matches
# no matches
# no matches
# Displaying 1 of 1 matches:
#  came into Havana . Within a week , however , I began to suspect that something
# no matches
# Displaying 1 of 1 matches:
# al values were limited . Avocados , however , are very rich in nutrients . Thei
# Displaying 2 of 2 matches:
# to destruction by nuclear weapons . However , because this vulnerability is mut
# killer problem is manned aircraft . However , the aircraft which we have today
# Displaying 2 of 2 matches:
# n's playing strikes me as finicky , however . Why , for example , does he favor
# ing you to your feet . In the end , however , the thing about this performance
# no matches
# Displaying 1 of 1 matches:
# may not do ; ; must and should do . However , there is a minimum of legislative
# Displaying 2 of 2 matches:
#  This is not necessarily to green , however , for in some situations only a yel
# r of fitting is not too important . However , we started with the first row of
# Displaying 4 of 4 matches:
# lved with mathematical problems ; ; however , he will have a clearer understand
# grammar school arithmetic classes . However , it is essential that the various
# ormula is as important as another . However , some formulas are used more than
# onvert the result to cubic inches . However , the displacement of the cylinder
# no matches
# no matches
# Displaying 1 of 1 matches:
# ds liqueur as optional . ) Vernon , however , held out for plain oyster roast ,
# Displaying 1 of 1 matches:
# he public areas and when on tours . However , the use of tripods is not allowed
# Displaying 1 of 1 matches:
# orn . Even when they are finished , however , the contrast will remain , for Is
# no matches
# no matches
# Displaying 1 of 1 matches:
# d and screwed to the first . Note , however , that it is six inches shorter at
# no matches
# Displaying 2 of 2 matches:
# rm until 1882 . The southern half , however , on account of its underbracing ,
# al counties . The Philippi bridge , however , was the Chenoweth master piece ,
# Displaying 4 of 4 matches:
# exactly a joy to behold . ( We do , however , recommend those patented covers t
# ment . The placement of your pool , however , will not of itself solve the two
#  , and the parking area . ) We do , however , provide a limited number of extra
#  of spring cleaning will be saved , however , if you remove the main drain grat
# no matches
# Displaying 2 of 2 matches:
# lanner to carry through the study . However , there is also much to be gained b
# ul radius equal in all directions . However , a narrow strip may be very practi
# Displaying 1 of 1 matches:
# a way of life for fellow citizens . However , in all of Prokofieff's music , yo
# Displaying 1 of 1 matches:
# e a color mixture as I can manage . However , first I thoughtfully study my ske
# Displaying 2 of 2 matches:
# ave flexibility . They often fail , however , to develop real abdominal , back
# hould be sufficient for solo . If , however , the child is weak , overweight ,
# no matches
# Displaying 2 of 2 matches:
# re a philosopher than a physicist . However , he continued experimenting and le
# imenting in the sciences . He was , however , fortunate in his contact with Pro
# no matches
# no matches
# Displaying 3 of 3 matches:
#  into architectural certification , however , would demand a prolonged study of
# ion for the educator in this case , however , would have to be raised to full a
# ted degrees at all . The question , however , cannot be ignored for long . The
# no matches
# no matches
# Displaying 1 of 1 matches:
# . Part of this headquarters staff , however , are engineering managers who work
# Displaying 1 of 1 matches:
# ply against weather contingencies . However , that is not all he has to do . He
# Displaying 1 of 1 matches:
# industry to the plastics industry , however , is not in terms of volume alone .
# no matches
# Displaying 5 of 5 matches:
# hen everything is strange and new . However , after you've seen all the histori
# 00 a day . The charge is variable , however , and goes as low as $.50 a day in
#  to choose from in most countries , however , including 6-passenger sedans and
# ee . In the majority of countries , however , the rates range from $3.00 to $3.
# ey do for the drive-yourself cars . However , whether you arrange to have a Eur
# Displaying 1 of 1 matches:
# tion . It is only fairly recently , however , that linguists have developed a s
# Displaying 1 of 1 matches:
#  terrible and inhumane weapons . `` However , evidence that the Axis powers are
# Displaying 2 of 2 matches:
# uivalents in our wakeful thoughts . However , readers who accept Freud's findin
# ly realistic continuity of dreams , however bizarre their combinations , denies
# no matches
# no matches
# Displaying 1 of 1 matches:
# tock in trade ; ; your livelihood . However , the last few years of your life ,
# no matches
# Displaying 4 of 4 matches:
# cannot be consummated . Generally , however , in such marriages as those cited
# b gin . Virtually everyone agrees , however , that the trend toward female sexu
#  next on the list . In some cases , however , domination of the sex act by one
# adjustment '' . Other experts say , however , that if sexual domination by one
# no matches
# Displaying 1 of 1 matches:
# s hesitate to quote exact figures , however , believing that any sum they come
# Displaying 1 of 1 matches:
# ning in hereditary predisposition . However , this does not mean that a child's
# Displaying 2 of 2 matches:
#  , on this side of the `` veil '' . However that may be , people are known to g
# ious '' moods and to clarify them . However , in the next visit that the resear
# Displaying 2 of 2 matches:
# ty . The savings are not as great , however , as is sometime supposed . Usually
# to hire someone to do the plowing , however . For larger plantings , you'll nee
# Displaying 1 of 1 matches:
# Affairs . Counsel for the defense , however , shrewdly allowing himself to be s
# Displaying 1 of 1 matches:
# asons . The Roman Catholic Church , however , sanctions a much more liberal pol
# Displaying 3 of 3 matches:
# nding that its coasts led nowhere , however , he turned north again , toward th
#  After three weeks' swift sailing , however , the ship entered an area of shall
# themselves . The important result , however , was that Juet and Francis Clemens
# no matches
# no matches
# Displaying 1 of 1 matches:
# klore in his poems . This has not , however , prevented publishers from labelin
# Displaying 1 of 1 matches:
#  county governments in 1928-29 '' . However , this inaugural feast did its spon
# Displaying 2 of 2 matches:
#  English coast . Tsunami are rare , however , in the Atlantic Ocean ; ; they ar
# it is plain that a warning system , however efficient , is not enough . In the
# Displaying 1 of 1 matches:
# e old-time trooper . The truth is , however , that when Mel Chandler first repo
# Displaying 2 of 2 matches:
# o draw cartoons about . I do mean , however , that I take them for granted , an
# of U.S. `` prestige '' . Prestige , however , is only a minor part of the probl
# no matches
# Displaying 5 of 5 matches:
# ned joining a synagogue or temple . However , they were hostile to Jewish Ortho
# win positions on the school teams . However , in their junior and senior years
# -old machinist observed irritably . However , among the girls , there are some
#  the faculty have been unavailing . However , a growing intellectual sophistica
# nd summers in Europe . In general , however , the timetable of travel lags cons
# no matches
# Displaying 1 of 1 matches:
# n occasion , be anything but that . However , by cultivating a wine dealer and
# no matches
# Displaying 1 of 1 matches:
# ation . His Ideas in this respect , however , sometimes arouse critical respons
# Displaying 3 of 3 matches:
# the only college in the Ivy group . However , three distinguished associated gr
# rs in the Ivy group . It is still , however , the junior member of the League ,
# span the other Ivies have enjoyed . However much football has been over-emphasi
# no matches
# Displaying 1 of 1 matches:
# y were not sufficiently challenging however , and she resigned in 1887 , to go
# Displaying 3 of 3 matches:
#  out-of-school youth . In general , however , it may be said that when a boy or
#  this regard in the Negro schools . However , the teacher can only go so far if
# e student's time in those years ; ; however , for slow learners and prospective
# Displaying 1 of 1 matches:
# s a medicine . This nondrying oil , however , is now more in demand than ever b
# Displaying 1 of 1 matches:
# e term bein' restricted to cattle , however , as hosses , under like circumstan
# Displaying 3 of 3 matches:
# recinct '' ? ? Intuition told him , however , that she was tired and winded fro
# ing jump , it could get into gear . However nothing on four legs was supposed t
# ted as before . This new position , however , gave the ropers a better chance .
# Displaying 2 of 2 matches:
# ed `` lower levels '' . The truth , however , is that the ecumenical church is
# communicated to all congregations . However needed this may be , the fundamenta
# Displaying 3 of 3 matches:
# home . The ordinary man and woman , however , saw little of the great professio
# any importance . Radio broadcasts , however -- now that even plain people could
# t the batter hit the ball . Radio , however , so increased the interest of wome
# Displaying 4 of 4 matches:
# cular and of the world in general . However , as Erickson has noted , the indiv
# couraged to develop some autonomy . However , if the child has been constantly
# ts , and having created something ( however small or simple -- even a doll dres
# d and most likely to become fixed , however , in those who have had no or very
# no matches
# no matches
# Displaying 2 of 2 matches:
# urious about the African reaction . However , the chaos on my desk prevented my
# s one takes refuge in the theory -- however disguised -- that Negroes are , som
# Displaying 2 of 2 matches:
# rrative time and film time Melies , however , out of his professional instincts
#  produced on film . It was Porter , however , who produced the very first movie
# Displaying 3 of 3 matches:
# lis ; ; congregational membership , however , is another thing . A congregation
#  recruitment ; ; this recruitment , however , must follow the pattern of econom
# rches ; ; one study in Pittsburgh , however , has illuminated the situation . I
# Displaying 3 of 3 matches:
#  four years . Venturesome traders , however , continued to come to them from Mo
#  war broke out . Perier's efforts , however , were on the whole ineffective in
# goods . He did find some to trust , however , and he employed the King's soldie
# Displaying 1 of 1 matches:
#  to Moscow . The principal mauler , however , was Senator Joseph McCarthy . Whe
# Displaying 1 of 1 matches:
#  -- I did explain to the students , however , that this was not my usual style
# Displaying 4 of 4 matches:
# ed , and to legal remedies . This , however , is sufficient to show that more o
# n them indirectly and secondarily ( however inevitably ) and not by deliberate
# m this -- in the order of justice . However , it is also a Christian insight to
# r values '' . A trial of strength , however , is made quite inevitable by virtu
# Displaying 1 of 1 matches:
# y support ? ? I am concerned here , however , with the Northern liberal's attit
# Displaying 7 of 7 matches:
# us changes in world politics have , however , thrown it into confusion , so muc
# s strictly national in motivation , however much other nations ( e.g. , the Uni
# til well into the present century . However , in recent decades , for what doub
# gislation . Of greater importance , however , is the content of those programs
# ion . The content is not the same , however : rather than individual security ,
# reak greatest harm . Historically , however , the concept is one that has been
# ce from outside control . In fact , however , both principles have always been
# Displaying 1 of 1 matches:
# absolutely certain of the answers . However , the system is designed , ingeniou
# Displaying 2 of 2 matches:
# Suddenly , however , their posture changed and the gam
# ines and their language . Finally , however , the arrangements were made and we
# Displaying 1 of 1 matches:
# called `` historical monuments '' . However , just as all the buildings have no
# Displaying 1 of 1 matches:
# st and had even performed as such . However , when he assumed the duties of a c
# no matches
# Displaying 1 of 1 matches:
# m renaissance . It is interesting , however , that despite this strong upsurge
# Displaying 2 of 2 matches:
#  energies . He is still concerned , however , with a personal event . He accept
#  dictates as faithfully as he can . However , there is always the possibility t
# Displaying 2 of 2 matches:
# ut it ) . I think it is essential , however , to pinpoint here the difference b
# mited to one term . These are not , however , differences in federal structure
# no matches
# no matches
# no matches
# Displaying 2 of 2 matches:
#  cannot feel length in the number , however large . In a stream that turns a mi
# f misinterpretation . We were not , however , entirely unacquainted with the va
# Displaying 2 of 2 matches:
# ccasional touch of genius ( which , however , does not know `` how to attack th
# nt tendency of Mann's early tales , however pictorial or even picturesque the s
# Displaying 1 of 1 matches:
# ds the involvement of all persons , however humble , in a divine drama . The ar
# Displaying 1 of 1 matches:
# Newman said to his adversaries ) `` however bad I may be , you're not quite the
# Displaying 5 of 5 matches:
#  be satisfied by surface . It may , however , be noted that his gift for color
# te it in the present . He did not , however , find himself at once . His next m
# sumed its traditions . He did not , however , settle back into acquiescence wit
# s was Julius Caesar . His purpose , however , was not to establish an empire ,
# s the worst of losers . There are , however , some wonderful chapters at the be
# Displaying 2 of 2 matches:
# eal . Even on the fictional level , however , the contradictions which give ris
# More profound and more disturbing , however , is the moral isolation of Raymond
# Displaying 1 of 1 matches:
# easurable properties of a command . However , for convenience we will stick to
# Displaying 6 of 6 matches:
# drift to the Religion of Humanity , however , prepared the way for a reception
#  physiognomy of the Little People . However , it is important to trace the phil
# t has not always been clear to us , however . This notion of the General Will g
# oderates . He opens his discourse , however , with a review of the Eisenhower i
# argin of his preferment . This is , however , symptomatic of our national malai
# rve discussion of it for a moment , however , to return to President Kennedy .
# no matches
# Displaying 3 of 3 matches:
# fectly safe . Despite this danger , however , we are informed on every hand tha
# l keep the sheriff away '' . That , however , may also bring the police , if th
# tual bankruptcy . We are reminded , however , that freedom of thought and discu
# no matches
# Displaying 4 of 4 matches:
# menological life . The third type , however , wrenches attention from the life
# s as partially experienced . This , however , cannot be done by a community who
# iritual forces into the situation . However , the crisis occurs precisely as a
# s been called various names , all , however , pointing to the same basic experi
# no matches
# Displaying 1 of 1 matches:
# ne by the old masters '' . Helion , however , clung to the belief that `` in es
# Displaying 2 of 2 matches:
#  the planter society did not come , however , until after the Civil War when So
# y have an ancestry extending back , however , at least to 1728 , when William B
# Displaying 3 of 3 matches:
# er nations . As things turned out , however , we have not profited greatly from
# stitutions , in Santa Barbara . But however we come , finally , to explain and
# es . The reality of the situation , however , is described by Mr. Lyford : `` M
# Displaying 2 of 2 matches:
# ) be incomplete . Circular motion , however , since it is eternal and perfectly
# body problem . In Ptolemaic terms , however , eclipses and retrograde motion we
# Displaying 1 of 1 matches:
#  pretty sister Rachel . Henrietta , however , was at that time engaged in a len
# no matches
# Displaying 3 of 3 matches:
# umble of excuse , I fled . I fled , however , not from what might have been the
# n that sense I can never be again . However , I confess my hope that I will be
# may , like paradise , be regained . However , it was not of innocence in genera
# Displaying 2 of 2 matches:
# with the guitar . It is a mistake , however , to imagine that Sandburg uses the
# he said . The parents compromised , however , on a convent school and Paula wen
# no matches
# no matches
# no matches
# no matches
# Displaying 2 of 2 matches:
# 's personality ever since . It is , however , a disarming disguise , or perhaps
# t to need any actor at the moment , however . For him Mercer produced the lyric
# Displaying 1 of 1 matches:
# most affable . There was one time , however , when his face clouded and he sudd
# no matches
# Displaying 3 of 3 matches:
# s to this appraisal . Undoubtedly , however , the significance of the volume is
# mind and usage of Gentile and Jew . However , in the context of legal and civic
#  are sought . For what we propose , however , a psychoanalyst is not necessary
# no matches
# no matches
# no matches
# Displaying 1 of 1 matches:
# rive . Nineteenth-century virtues , however , seem somehow to have gone out of
# Displaying 2 of 2 matches:
#  my principles . These principles , however , will not be served by violence in
#  into Germany . The special guard , however , was still posted on Kehl bridge .
# Displaying 1 of 1 matches:
# erman's most serious shortcomings , however , was his mistrust of his cavalry .
# no matches
# Displaying 1 of 1 matches:
# On arrival at headquarters he had , however -- in King Stanislas' words to Glay
# Displaying 1 of 1 matches:
# dentify each design . It remained , however , for Mando to teach me that Doric
# Displaying 1 of 1 matches:
#  The bulk of his early reputation , however , came not from his poetry or his m
# Displaying 3 of 3 matches:
#  of law . Gorton appeared for her , however , and what he told the magistrates
# nd get it '' . Gorton and company , however , promptly bought land from Mianton
# ling down on the embattled Gorton . However , the General Court at Boston order
# no matches
# no matches
# Displaying 3 of 3 matches:
# . By the time they reach that age , however , Aristotle no longer worries about
# ose of evaluation . But there are , however , several features of Aristotle's a
# fense . What is not so well known , however , and what is quite important for u
# no matches
# Displaying 2 of 2 matches:
#  . In his dealings with offenders , however , Morgan was typically firm but jus
#  intelligence obtained . Meantime , however , this same General Smallwood seeme
# no matches
# no matches
# Displaying 3 of 3 matches:
# e knowledge of Germanic philology , however , it is debatable whether their use
# n by Lappenberg and Kemble . They , however much they were in disagreement with
# ed by '' theory . In recent years , however , a wind of change seems to be blow
# no matches
# no matches
# no matches
# Displaying 2 of 2 matches:
# r insights they needed to possess . However , as a practicing historian , he ,
# nts for a proper study of history . However , despite the insight of many of hi
# Displaying 2 of 2 matches:
# e nothing more to do with them '' . However , at eighty-five , he had still bee
# ger of a new tyranny ahead . `` But however we go , whatever our doom , it will
# no matches
# Displaying 1 of 1 matches:
# might take up the case . It would , however , reach the proctors and other offi
# Displaying 1 of 1 matches:
#  . Not all recent science fiction , however , is dystopian , for the optimistic
# Displaying 1 of 1 matches:
#  simply too old to hope . I would , however , like to suggest that , wrong thou
# Displaying 4 of 4 matches:
# een '' . Even in its present form , however , the first part of Malraux's unrec
# nt `` contradictions '' . Nothing , however , could be farther from the truth .
# y , his secret faith in endurance , however crammed with catastrophes , the sam
# y , he is any man whose reasoning , however elementary it may be , affects and
# Displaying 2 of 2 matches:
#  . I believe that these proposals , however meritorious in terms of world needs
# erve a useful purpose . Generally , however , there is an abundance of availabl
# Displaying 1 of 1 matches:
# rm and presentation of his poetry . However , his subject matter and basic them
# Displaying 1 of 1 matches:
#  the war '' but they fought in it , however reluctantly ; ; they sweated out so
# no matches
# no matches
# Displaying 2 of 2 matches:
# t of the less developed countries , however , such programing is at best inadeq
# country programs . In such a case , however , we would encourage the recipient
# Displaying 1 of 1 matches:
# national seas . I prefer to speak , however , of Sam Rayburn , the person , rat
# Displaying 2 of 2 matches:
# in ease of audit time and payment . However , they lend themselves to abuse and
# nd other allied matters . In 1942 , however , the nation was at war . Gasoline
# Displaying 2 of 2 matches:
# y are doing now . It is not clear , however , whether they are thinking of all
# ue on some boats for tax purposes . However , few are taxed , and the owners an
# no matches
# Displaying 5 of 5 matches:
# special districts in Rhode Island . However , a word should be mentioned in reg
#  powers . Unlike cities and towns , however , they do not have to submit any fi
# tate , city and local governments . However , only Illinois , Oregon , Louisian
# as painful as is commonly thought . However , it must be stressed that much dep
# cal tax collection year calendars . However , neither of these two cities is on
# no matches
# no matches
# no matches
# Displaying 1 of 1 matches:
# atures for the bulk liquid helium . However , the surface temperature gradient
# Displaying 1 of 1 matches:
# ve upon the Commission : Provided , however , That the total amount of the fees
# Displaying 3 of 3 matches:
# In the light of the facts at hand , however , New York Central intends to pursu
# s to the lines that wish to merge . However , there is a more profound consider
# we can't stop them from coming in , however , just by talk . A naval blockade w
# no matches
# Displaying 1 of 1 matches:
# o allow use of the whole basement . However , as much time as possible should b
# Displaying 3 of 3 matches:
# al Motors '' . 353 U. S. , at 606 . However , it determined that neither this f
# racies to monopolize , such trade . However , this Court put to one side withou
# sts of their own companies . This , however , did not bar finding that Du Pont
# Displaying 3 of 3 matches:
#  to do so . He was not prosecuted , however , and his case was subsequently reo
#  and service . On March 21 , 1957 , however , the Department recommended approv
# '' was in 1952 . The appeal board , however , unanimously concurred in the Depa
# no matches
# Displaying 2 of 2 matches:
# of time is greatest . There would , however , be a variety of other skills -- m
# ke many friends . It is important , however , that the Peace Corps be advanced
# no matches
# Displaying 1 of 1 matches:
# rategic weapon system is doubtful . However , I am recommending that developmen
# no matches
# Displaying 1 of 1 matches:
#  of little practical significance . However , in this case as elsewhere it was
# Displaying 1 of 1 matches:
# x returns are due April 16 , 1962 . However , if their United States income is
# no matches
# Displaying 1 of 1 matches:
# e 1850's and early 60's . In 1868 , however , a truce was called between the co
# Displaying 2 of 2 matches:
#  1961 will be lower than for 1960 . However , the healthy inventory position of
# ely the same as our present plant . However , its modern one-story layout is de
# no matches
# Displaying 3 of 3 matches:
# ion against 5.7 million in 1959 ; ; however , production came to only 5.6 milli
#  quite bright . For the near term , however , it must be realized that the indu
# sales should slightly exceed 1960 , however , and reach $1.9 billion . Replacem
# Displaying 2 of 2 matches:
# pro forma . They can be effective , however , if their members set high standar
# Before deciding where it is going , however , a college or university must know
# Displaying 1 of 1 matches:
#  resolved . It should be possible , however , to put useful limits on the diame
# Displaying 2 of 2 matches:
# or will modify these conditions ; ; however , the anode is still the part recei
# als should be usable in principle . However , technical difficulties arise by m
# Displaying 3 of 3 matches:
# ives a rate of shear of Af . This , however , can only be considered approximat
# an be considered exploratory only . However , they do demonstrate the presence
# ops to confirm the above formulas . However , there are photographs of suspende
# Displaying 3 of 3 matches:
# volume per oxygen is about normal . However , the possible absence of a center
# rs and Af those on the other side . However , any oxygen nonequivalence would s
#  Cr as compared with 61.2% theory . However , Af adsorbs water from the atmosph
# Displaying 1 of 1 matches:
# ace irregularities to some extent . However , a major factor in binding dirt is
# no matches
# Displaying 2 of 2 matches:
# apolated to meteoritic velocities . However , one must expect that vaporization
# 0-M-diameter sphere of density Af . However , the conversion from mass to size
# Displaying 2 of 2 matches:
#  existence . Very small particles , however , in a size range of 1 to 4 microns
# utralized . It must be remembered , however , that there are many agents for wh
# Displaying 1 of 1 matches:
# s were used to test each sample ; ; however , in the interest of clarity and co
# no matches
# Displaying 3 of 3 matches:
# eported in 1944 by Emmett R. Dunn . However , as a field measurement , it is op
# t and can be accepted as probable . However , many herpetologists remain skepti
# ` normal '' newly born individual . However , as so many of the records are not
# Displaying 6 of 6 matches:
# p throughout . The pulmonary vein , however , without the limiting supportive t
# ( ( fig. 24 ) . This relationship , however , is not maintained centrally . Her
# logic differences been determined . However , the dynamics of airflow , from mo
# rk of Miller ( '50 ) . Apparently , however , Miller has relied heavily on the
# s found in the horse is not clear . However , this artery is known to be a nutr
# existence in that species . It is , however , highly suggestive and agrees well
# no matches
# Displaying 3 of 3 matches:
#  not as yet completely understood . However , the formation of organically boun
# odinated . Iodination of tyrosine , however , is not enough for the synthesis o
# roid drugs of the thiouracil type , however , are not antagonised by such means
# no matches
# Displaying 1 of 1 matches:
# ht green nonspecific fluorescence . However , the nonspecific staining by the A
# Displaying 1 of 1 matches:
# ed conditioned reactions reappear . However , if these procedures are applied m
# Displaying 1 of 1 matches:
# fact that it is a linear operator . However , one does not need to know very mu
# no matches
# no matches
# Displaying 2 of 2 matches:
#  the pencil which meets its image . However , since the pencil contains a secan
# f the general lines of the pencil . However , if there is no additional complex
# Displaying 1 of 1 matches:
# rt of a larger development effort , however , it may gain wide acceptance . It
# Displaying 1 of 1 matches:
# rt of it . In societies like ours , however , its place is less clear and more
# no matches
# Displaying 4 of 4 matches:
# expected adherence to group norms . However , because of Church laws , lately m
# er system or within the subgroups . However , it cannot be presumed , informal
# as in the case of this population . However , the factor of physical isolation
# f this group . This conclusion is , however , an over-simplification . A more r
# Displaying 2 of 2 matches:
# cation of demographic information . However , the statistical offices of both g
# s used for the new investigations . However , the differences in procedure are
# Displaying 1 of 1 matches:
# lly functional for these students . However , all admitted that the `` hindsigh
# Displaying 1 of 1 matches:
# in which she relinquished control . However , she was able to relax and yield t
# no matches
# Displaying 2 of 2 matches:
# and was regarded as a `` comer '' . However , he turned out to be a complete fa
# ls threatened and defends himself . However , in this case the district manager
# no matches
# no matches
# Displaying 2 of 2 matches:
# ct . Adverbial second complements , however , are likely not to have dominant s
# mission of a subordinator pronoun , however , does not result in an increase in
# Displaying 5 of 5 matches:
# to account for this . Improvement , however , is urgent , and at least three th
# e small differences between tones . However , any such suggestion accounts for
#  explanation of tone difficulties , however , does not apply in all languages .
# port these morphophonemic systems , however , are very different . The inventor
#  deserve in Kikuyu circles . This , however , will not exhaust their practical
# Displaying 1 of 1 matches:
# ; ; or both . The differentiation , however , is not very much greater , as sho
# Displaying 1 of 1 matches:
# esumably for the peace conference . However , there was no real question of the
# Displaying 2 of 2 matches:
# ions was generally above reproach . However , the regionally differentiated res
# the electoral process . Centrally , however , the administrative problem was mo
# Displaying 2 of 2 matches:
# ts , and are not guaranteed a job . However , there always is some limit to the
# benefit employers in other states . However , if Federal funds are used , it wo
# Displaying 1 of 1 matches:
# nt of forethought and calculation , however elaborate . Thus while his theory o
# Displaying 5 of 5 matches:
# e easier to obtain . At this time , however , there are signs that increased av
#  publicly offered corporate bonds . However , as witnessed by the large corpora
# e position for the banking system . However , the monetary authorities will con
# o long-term Government securities . However , to the extent that the monetary a
# economic prospects of the Sixties . However , the impact of a rising rate of ho
# Displaying 4 of 4 matches:
#  previous price increase . Notice , however , that the passage of time does not
# nded to anticipated levels of GNP , however -- only the current level of GNP af
# , and so forth . As we have noted , however , we are abstracting from changes i
# te an argument for raising prices . However , it is not known to either the uni
# Displaying 1 of 1 matches:
# ation of the `` sovereign will '' . However , the sovereign was not Hobbes' abs
# Displaying 1 of 1 matches:
# ty in the meaning of national law , however , state interpretations are subject
# Displaying 2 of 2 matches:
# cquisition . The Ruling would not , however , apply to an acquisition of assets
# ortization over a 60-month period . However , a similar privilege was not speci
# Displaying 1 of 1 matches:
# onnaire . Under the circumstances , however , the team considered it would prov
# Displaying 3 of 3 matches:
# operating control over the system . However , when labor disputes arise , its p
# f course , obeyed the court order . However , the Attorney General of Californi
# s Regulation was being challenged . However , the Federal Court held that since
# Displaying 5 of 5 matches:
# rst few years of the child's life . However , the teacher who understands the i
#  fourth year it begins to decline . However , as we have seen , in later childh
#  cooperate . In the middle grades , however , he begins to participate more eff
# ren . It is the classroom teacher , however , who has daily contacts with pupil
# is classroom . He can be expected , however , to examine and interpret the info
# no matches
# Displaying 1 of 1 matches:
# ower-class interests in education . However , there are relatively few such pol
# Displaying 3 of 3 matches:
# Unfortunately , however , and for reasons to be discussed i
# some return on capital investment , however low , the rates of charge for this
# att-hour of consumption . In fact , however , the problem is not so simple . Fo
# Displaying 2 of 2 matches:
# ot descend to pure sensationalism . However , when philosophy attempts to stand
# seem a modest role for philosophy . However , modesty and triviality are differ
# no matches
# Displaying 3 of 3 matches:
#  affected '' . The authors insist , however , that these abnormalities in the s
# whatever it turned out to be . If , however , the figure to be discerned were c
# one would surmise , the procedure , however , could be repeated with the same o
# Displaying 7 of 7 matches:
# ubjective judgment . At the least , however , one may conclude that Geometric p
# ry inspection of its many aspects , however , the historian can deduce several
# rywhere within the common pattern , however , one finds local diversity ; ; Gre
#  only dimly , and yet the results , however general , are worth the search . Th
# ally across the century . The era , however , is Janus-faced . While many token
# ly Greece ; ; the important point , however , is that these magnificent achieve
#  progress . To the ancestral lore , however , new materials were added . Painte
# no matches
# no matches
# Displaying 1 of 1 matches:
#  is a trustee for the common good , however feeble the safeguards which the pos
# Displaying 4 of 4 matches:
# pendence . During the Brown trial , however , the state's most powerful Democra
# rved the extreme penalty , no man , however criminal , ought to suffer the pena
# ders of the Providence Daily Post , however , learned that it was generally con
# hy . The Providence Daily Journal , however , stated that Brown's courage , bra
# Displaying 2 of 2 matches:
# areas . In certain other pictures , however , Braque began to paint areas in ex
#  The accumulation of such devices , however , soon had the effect of telescopin
# Displaying 4 of 4 matches:
# lt from scratch at today's prices . However , the building of freeways and gara
# n unit sales have been decreasing , however , his dollar volume continues to ri
# discover . When all has been said , however , the big branch store remains a ma
# from downtown by traffic problems , however , the city store can only pressure
# Displaying 1 of 1 matches:
# vering joints . Experience showed , however , that it is very difficult to pain
# no matches
# no matches
# Displaying 2 of 2 matches:
# act . Once he has been identified , however , a new melody is used to accompany
# The most unusual feature of Boris , however , is the use of the greatest charac
# Displaying 2 of 2 matches:
# lopment taken place . This is not , however , the case , and development is a t
#  of the time . In the later poems , however , the personal tone predominates .
# Displaying 1 of 1 matches:
# ty and power . A Tiepolo painting , however confabulated , is a universe of ten
# Displaying 3 of 3 matches:
# rs , unimportant ; ; the language , however , is a proper object of scrutiny ,
# ption of these epics rests partly , however , upon the degree to which they wer
#  any poem is formulaic it is idle , however , to inspect nothing besides lines
# Displaying 1 of 1 matches:
# h a perspective . In his analysis , however , he touches upon but fails to expl
# Displaying 4 of 4 matches:
# ting of this table may be altered , however , as described in the 7070/7074 Dat
#  . Extreme caution should be used , however , to avoid the conflicting usage of
# ich it was reserved . It will not , however , be used for symbolic assignment u
#  an electronic switch . It cannot , however , be referred to by electronic swit
# no matches
# Displaying 2 of 2 matches:
# enemy's building and base complex , however , requires attacks on enemy territo
# o be for use in restricted waters , however , and targets must come within a fe
# Displaying 4 of 4 matches:
# lite 1 , isolated from the medium , however , showed a lower specific activity
# d not hold here . It was possible , however , to decompose the compliance into
# in the area . The gallium content , however , has been enhanced five-fold . Thi
# d deuterated alcohols as solvents , however , has given evidence that metal-hyd
# Displaying 1 of 1 matches:
# not a primary aim of this project . However , the proposed correlation of the m
# Displaying 7 of 7 matches:
# oon dispelled . Interest remained , however , in the possibility that it would
# emical spoilage of food . It will , however , inhibit the sprouting of potatoes
# as regards taste and palatability , however , at dosages substantially less tha
# n are foreseen . Such projections , however , appear highly speculative and the
#  beef from 5 days to 5 or 6 weeks . However , the problem of consumer acceptabi
# inctly improved keeping qualities . However , a major problem here is one of sc
# urization is likely to be delayed , however , for two reasons : ( 1 ) the stora
# Displaying 2 of 2 matches:
# g tests . The instrumental method , however , is about 100 times more sensitive
# gh the origin and having slope Af . However , in the actual assessment of the c
# Displaying 1 of 1 matches:
# g . It might be well to point out , however , some of the newer developments th
# no matches
# Displaying 4 of 4 matches:
#  high-gain values ; ; they suffer , however , from an inherently low resolution
# btainable resolution is concerned . However , the unavoidable low-duty cycle re
#  showing high gain and resolution . However , electrostatic focus , important f
# ber couplers . It should be noted , however , that the paraxial resolution is q
# Displaying 2 of 2 matches:
# r will be of the order of Af . If , however , we are seeking the optimal R-stag
# in a probabilistic sense . We can , however , maximize its expected value . For
# Displaying 3 of 3 matches:
# hing of flight equipment circuits . However , the leveling operation can be mai
#  angle ) can be seen after a time . However , skill is required on the part of
# st be known for each launch point . However , this difficulty is not too seriou
# no matches
# no matches
# no matches
# no matches
# no matches
# Displaying 1 of 1 matches:
# duty to God and his own salvation . However , a boy's lively eyes might rove .
# no matches
# Displaying 3 of 3 matches:
#  culture . To Voltaire's surprise , however , their host gives them fresh cloth
# dinner . Immediately after dinner , however , Rousseau asks for still another f
# uldn't write . These little songs , however , were sweet nothings from the hear
# no matches
# no matches
# Displaying 1 of 1 matches:
# s knocked out . In this heavy air , however , that device did not seem to help
# Displaying 1 of 1 matches:
#  so harassed him twelve hours ago . However , the litter remained , augmented b
# no matches
# no matches
# Displaying 1 of 1 matches:
# ral . Joel knew what he was about , however . `` You're gonna get caught '' , s
# no matches
# no matches
# no matches
# Displaying 1 of 1 matches:
# thought that the eventual victory , however it was brought about , would be swe
# Displaying 2 of 2 matches:
# at there was a limit to tolerance , however brilliant , however far-famed the o
#  to tolerance , however brilliant , however far-famed the offender might be . H
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# Displaying 2 of 2 matches:
# e enough time to contemplate them , however ; ; in an instant the doctor was st
# he doctor's wits had not left him , however , for all his sixty-eight years , a
# no matches
# no matches
# no matches
# Displaying 1 of 1 matches:
# people passing by . After a while , however , a person's mind gets fed up and t
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# Displaying 1 of 1 matches:
# n the morning of Stanley's return , however , her strength left her . Two hours
# Displaying 1 of 1 matches:
# nd a little special . We were not , however , prepared for anything like the ap
# Displaying 1 of 1 matches:
# g automobiles for a possible lead . However , it was virtually impossible to sc
# no matches
# no matches
# Displaying 1 of 1 matches:
# . They discussed this possibility . However likely it was , Pauling said , he c
# no matches
# no matches
# Displaying 1 of 1 matches:
# r objections properly . Right now , however , he was still too worried about Je
# no matches
# no matches
# no matches
# no matches
# Displaying 1 of 1 matches:
#  take on overtones of a nightmare . However , Haney knew it was not a dream . H
# no matches
# no matches
# Displaying 1 of 1 matches:
# nd time involved are astronomical . However , we sent a third vessel out , a mu
# Displaying 5 of 5 matches:
# Gabriel was being asked to do now , however , was to re-examine all his basic a
#  of the reason for the long pause , however , did not make it seem any less lon
# f was not heading for the nursery , however . It seemed unlikely that her crew
# ck at him couldn't be argued with , however . The skiff was headed for the very
#  and about to reinstall the fuses , however , he hesitated . He had to have fus
# no matches
# Displaying 1 of 1 matches:
#  an ordinary , `` normal '' being . However , no diagram of her brain patterns
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# Displaying 2 of 2 matches:
# elt strongly attached to the hall , however , and hardly a day passed when I di
# to be wearing . I did not despair , however ; ; far from it ! ! I was constantl
# no matches
# no matches
# Displaying 1 of 1 matches:
# Along with this self-satisfaction , however , Joyce sensed a growing tension .
# no matches
# no matches
# no matches
# no matches
# Displaying 1 of 1 matches:
# test tangle . Over and above that , however , was his growing suspicion of Chuc
# no matches
# no matches
# Displaying 1 of 1 matches:
# ything but swarms of bees in them . However , when there's a job to be done , I
# no matches
# no matches
# no matches
# no matches
# no matches
# Displaying 1 of 1 matches:
# ather invincible . It wasn't that , however , which decided them not to go to A
# no matches
# no matches
# no matches
# no matches
# no matches
# Displaying 1 of 1 matches:
# e long legs were less than poetic , however . Zingggg-O ! ! Then the boy straig
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# Displaying 1 of 1 matches:
# over his cheekbones . The surface , however , was perfectly white . He was drin
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# Displaying 1 of 1 matches:
#  safely married to the right sort , however much in the early years of that mat
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# Displaying 3 of 3 matches:
# ey proceeded to search . The robe , however , was missing , for by that time Ba
# more or less harmless `` nut '' ! ! However while in his cell awaiting trial fo
# iola and her chaperon at her home . However , such a hotbed of gossip had grown
# Displaying 1 of 1 matches:
#  sink . They looked so formidable , however , so demanding , that I found mysel
# Displaying 1 of 1 matches:
# off the screen . At the same time , however , I availed myself of the services
# Displaying 1 of 1 matches:
# Up to date , however , his garden was still more or less
# no matches
# no matches
# no matches
# Displaying 1 of 1 matches:
# passage . We would have preferred , however , to have had the rest of the orche
# Displaying 3 of 3 matches:
# could accurately forecast it . If , however , it would help to intensify your a
# sfying part of his disintegration , however , was the masterly way the Buddha p
# nemesis haunting his footsteps '' . However one looks at it , therefore , I'd s

# %% [markdown]
# ◑ 8. Define a conditional frequency distribution over the Names corpus that allows you to see which initial letters are more frequent for males vs. females (cf. 4.4).

# %%
names = nltk.corpus.names
cfd = nltk.ConditionalFreqDist(
    (fileid, name[0])
    for fileid in names.fileids()
    for name in names.words(fileid))
cfd.plot()
print('\nend')

# %% [markdown]
# ◑ 9. Pick a pair of texts and study the differences between them, in terms of vocabulary, vocabulary richness, genre, etc. Can you find pairs of words which have quite different meanings across the two texts, such as monstrous in Moby Dick and in Sense and Sensibility?

# %% [markdown]
# ◑ 10. Read the BBC News article: UK's Vicky Pollards 'left behind' http://news.bbc.co.uk/1/hi/education/6173441.stm. The article gives the following statistic about teen language: "the top 20 words used, including yeah, no, but and like, account for around a third of all words." How many word types account for a third of all word tokens, for a variety of text sources? What do you conclude about this statistic? Read more about this on LanguageLog, at http://itre.cis.upenn.edu/~myl/languagelog/archives/003993.html.

# %% [markdown]
# ◑ 11. Investigate the table of modal distributions and look for other patterns. Try to explain them in terms of your own impressionistic understanding of the different genres. Can you find other closed classes of words that exhibit significant differences across different genres?

# %%
cfd = nltk.ConditionalFreqDist(
    (genre, word)
    for genre in brown.categories()
    for word in brown.words(categories=genre))
genres = ['news', 'religion', 'hobbies', 'science_fiction', 'romance', 'humor']
modals = ['can', 'could', 'may', 'might', 'must', 'will']
cfd.tabulate(conditions=genres, samples=modals)

# from the text: Observe that the most frequent modal in the news genre is will, 
#while the most frequent modal in the romance genre is could. 

# Other examples: can and will in hobbies, could in romance
# Out:
#                   can could   may might  must  will
#            news    93    86    66    38    50   389
#        religion    82    59    78    12    54    71
#         hobbies   268    58   131    22    83   264
# science_fiction    16    49     4    12     8    16
#         romance    74   193    11    51    45    43
#           humor    16    30     8     8     9    13

# %% [markdown]
# ◑ 12. The CMU Pronouncing Dictionary contains multiple pronunciations for certain words. How many distinct words does it contain? What fraction of words in this dictionary have more than one possible pronunciation?

# %%
from nltk import FreqDist
entries = nltk.corpus.cmudict.entries()
words = [word for word, pron in entries]
unique_words = set(words)
print(len(unique_words))

counts = FreqDist(words)
repeated_words = [word for word in counts if counts[word] > 1]
print(len(repeated_words)/len(unique_words))
print('\nend')
# Out:
# 123455
# 0.07485318537118789
#
# end

# %% [markdown]
# ◑ 13. What percentage of noun synsets have no hyponyms? You can get all noun synsets using wn.all_synsets('n').

# %%
from nltk.corpus import wordnet as wn
wn.synsets('n')
# Out:
# [Synset('nitrogen.n.01'),
#  Synset('north.n.03'),
#  Synset('newton.n.02'),
#  Synset('normality.n.02'),
#  Synset('n.n.05')]

# %% [markdown]
# ◑ 15. Define a function supergloss(s) that takes a synset s as its argument and returns a string consisting of the concatenation of the definition of s, and the definitions of all the hypernyms and hyponyms of s.

# %%
def supergloss(s):
    print('not done')

# %% [markdown]
# ◑ 16. Write a program to generate a table of lexical diversity scores (i.e. token/type ratios), as we saw in 1.1. Include the full set of Brown Corpus genres (nltk.corpus.brown.categories()). Which genre has the lowest diversity (greatest number of tokens per type)? Is this what you would have expected?
